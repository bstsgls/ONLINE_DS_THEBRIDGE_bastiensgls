# %%
import pandas as pd

# %%
df_azuelas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/azuelas.csv")
df_azuelas
# Out:
#      adzeID Context_artefacts::Site                  Category  \
# 0       562              Abu Rawash               model blade
# 1       563              Abu Rawash               model blade
# 2       558              Abu Rawash               model blade
# 3        67              Abu Rawash               model blade
# 4       103              Abu Rawash               model blade
# ..      ...                     ...                       ...
# 289     833                 Saqqara  full size artefact blade
# 290     834                 Saqqara  full size artefact blade
# 291     556                 unknown  full size artefact blade
# 292     631                 unknown  full size artefact blade
# 293     632                 unknown  full size artefact blade
#
#     Context_artefacts::Region                   Context_artefacts::Period  \
# 0             Memphite region                      Old Kingdom, Dynasty 5
# ...

# %%
df_tipi_azuelas = pd.DataFrame([df_azuelas.nunique(), df_azuelas.nunique()/len(df_azuelas) * 100, df_azuelas.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_azuelas
# Out:
#                                    Card     %_Card     Tipo
# adzeID                              294      100.0    int64
# Context_artefacts::Site              17   5.782313   object
# Category                              4   1.360544   object
# Context_artefacts::Region            12   4.081633   object
# Context_artefacts::Period             9   3.061224   object
# Context_artefacts::Type of context    8   2.721088   object
# Type                                  4   1.360544   object
# Length of artefact                   73  24.829932  float64
# Width of artefact                    48  16.326531  float64
# Thickness of artefact                26   8.843537  float64
# Lower width of butt                   0        0.0  float64
# Width of butt                        44  14.965986  float64
# Thickness of butt                    27   9.183673  float64
# Lower thickness of butt               0        0.0  float64
# Thickness of blade                   23   7.823129  float64
# ...

# %%
df_tipi_azuelas["Clasificada_como"] = "Categorica"
df_tipi_azuelas.loc[df_tipi_azuelas.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_azuelas.loc[df_tipi_azuelas["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_azuelas.loc[df_tipi_azuelas["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_azuelas
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# adzeID                              294      100.0    int64  Numerica Continua
# Context_artefacts::Site              17   5.782313   object  Numerica Discreta
# Category                              4   1.360544   object         Categorica
# Context_artefacts::Region            12   4.081633   object  Numerica Discreta
# Context_artefacts::Period             9   3.061224   object         Categorica
# Context_artefacts::Type of context    8   2.721088   object         Categorica
# Type                                  4   1.360544   object         Categorica
# Length of artefact                   73  24.829932  float64  Numerica Discreta
# Width of artefact                    48  16.326531  float64  Numerica Discreta
# Thickness of artefact                26   8.843537  float64  Numerica Discreta
# Lower width of butt                   0        0.0  float64         Categorica
# ...

# %%
df_hachas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/hachas.csv")
df_hachas
# Out:
#      axeID Context_artefacts::Site Context_artefacts::Region  \
# 0      101              Abu Rawash           Memphite region
# 1      103                  Abusir           Memphite region
# 2      338                  Abusir           Memphite region
# 3      296                  Abusir           Memphite region
# 4      393                  Abusir           Memphite region
# ..     ...                     ...                       ...
# 148    177                 Saqqara           Memphite region
# 149    312                 Saqqara           Memphite region
# 150    301                 Saqqara           Memphite region
# 151    429                 Saqqara           Memphite region
# 152    297                 unknown                   unknown
#
#                        Category Context_artefacts::Period  \
# 0      full size artefact blade    Old Kingdom, Dynasty 4
# 1                   model blade    Old Kingdom, Dynasty 5
# ...

# %%
df_tipi_hachas = pd.DataFrame([df_hachas.nunique(), df_hachas.nunique()/len(df_hachas) * 100, df_hachas.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_hachas
# Out:
#                                    Card     %_Card     Tipo
# axeID                               153      100.0    int64
# Context_artefacts::Site              17  11.111111   object
# Context_artefacts::Region            11   7.189542   object
# Category                              5   3.267974   object
# Context_artefacts::Period             9   5.882353   object
# Context_artefacts::Type of context    7   4.575163   object
# Type                                  3   1.960784   object
# Heigth of artefact                   35  22.875817  float64
# Maximal width                        38  24.836601  float64
# Maximal thickness                    12   7.843137  float64
# Width of blade                       19  12.418301  float64
# Thickness of blade                    4   2.614379  float64
# Weight                               27  17.647059  float64

# %%
df_tipi_hachas["Clasificada_como"] = "Categorica"
df_tipi_hachas.loc[df_tipi_hachas.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_hachas.loc[df_tipi_hachas["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_hachas.loc[df_tipi_hachas["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_hachas
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# axeID                               153      100.0    int64  Numerica Continua
# Context_artefacts::Site              17  11.111111   object  Numerica Discreta
# Context_artefacts::Region            11   7.189542   object  Numerica Discreta
# Category                              5   3.267974   object         Categorica
# Context_artefacts::Period             9   5.882353   object         Categorica
# Context_artefacts::Type of context    7   4.575163   object         Categorica
# Type                                  3   1.960784   object         Categorica
# Heigth of artefact                   35  22.875817  float64  Numerica Discreta
# Maximal width                        38  24.836601  float64  Numerica Discreta
# Maximal thickness                    12   7.843137  float64  Numerica Discreta
# Width of blade                       19  12.418301  float64  Numerica Discreta
# ...

# %%
df_cinceles = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/cinceles.csv")
df_cinceles
# Out:
#      chiselID Context_artefacts::Site Context_artefacts::Region  \
# 0         174              Abu Rawash           Memphite region
# 1         175              Abu Rawash           Memphite region
# 2         957              Abu Rawash           Memphite region
# 3         958              Abu Rawash           Memphite region
# 4         959              Abu Rawash           Memphite region
# ..        ...                     ...                       ...
# 615       375                 unknown                     Nubia
# 616       377                 unknown                   unknown
# 617       376                 unknown                   unknown
# 618       378                 unknown                       NaN
# 619       379                 unknown                   unknown
#
#                            Category Context_artefacts::Period  \
# 0                       model blade    Old Kingdom, Dynasty 5
# 1                       model blade    Old Kingdom, Dynasty 5
# ...

# %%
df_tipi_cinceles = pd.DataFrame([df_cinceles.nunique(), df_cinceles.nunique()/len(df_cinceles) * 100, df_cinceles.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_cinceles
# Out:
#                                    Card     %_Card     Tipo
# chiselID                            620      100.0    int64
# Context_artefacts::Site              19   3.064516   object
# Context_artefacts::Region            12   1.935484   object
# Category                              5   0.806452   object
# Context_artefacts::Period            10   1.612903   object
# Context_artefacts::Type of context    8   1.290323   object
# Type                                  9   1.451613   object
# Length of chisel                    119  19.193548  float64
# Thickness of blade                   23   3.709677  float64
# Width of blade                       61    9.83871  float64
# Maximal width                        80  12.903226  float64
# Maximal thickness                    59   9.516129  float64
# Weight                              103  16.612903  float64

# %%
df_tipi_cinceles["Clasificada_como"] = "Categorica"
df_tipi_cinceles.loc[df_tipi_cinceles.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_cinceles.loc[df_tipi_cinceles["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_cinceles.loc[df_tipi_cinceles["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_cinceles
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# chiselID                            620      100.0    int64  Numerica Continua
# Context_artefacts::Site              19   3.064516   object  Numerica Discreta
# Context_artefacts::Region            12   1.935484   object  Numerica Discreta
# Category                              5   0.806452   object         Categorica
# Context_artefacts::Period            10   1.612903   object         Categorica
# Context_artefacts::Type of context    8   1.290323   object         Categorica
# Type                                  9   1.451613   object         Categorica
# Length of chisel                    119  19.193548  float64  Numerica Discreta
# Thickness of blade                   23   3.709677  float64  Numerica Discreta
# Width of blade                       61    9.83871  float64  Numerica Discreta
# Maximal width                        80  12.903226  float64  Numerica Discreta
# ...

# %%
df_espejos = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/espejos.csv")
df_espejos
# Out:
#      mirrorID Context_artefacts::Site     Context_artefacts::Region  \
# 0          60                  Abydos                        Abydos
# 1         208                  Abydos                        Abydos
# 2         304                  Abydos                        Abydos
# 3          52                 Adindan                         Nubia
# 4         273                   Aniba                         Nubia
# ..        ...                     ...                           ...
# 121       300                 unknown                       unknown
# 122       301                 unknown                       unknown
# 123       303                 unknown                       unknown
# 124       260      Zawiyet el-Mayitin  between Fayum and Beni Hasan
# 125       259      Zawiyet el-Mayitin  between Fayum and Beni Hasan
#
#                      Category                      Context_artefacts::Period  \
# ...

# %%
df_tipi_espejos = pd.DataFrame([df_espejos.nunique(), df_espejos.nunique()/len(df_espejos) * 100, df_espejos.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_espejos
# Out:
#                                    Card     %_Card     Tipo
# mirrorID                            126      100.0    int64
# Context_artefacts::Site              26  20.634921   object
# Context_artefacts::Region            13   10.31746   object
# Category                              3   2.380952   object
# Context_artefacts::Period             8   6.349206   object
# Context_artefacts::Type of context    7   5.555556   object
# Type                                  6   4.761905   object
# Heigth of artefact                   42  33.333333  float64
# Width of artefact                    43  34.126984  float64
# Thickness of artefact                13   10.31746  float64
# Heigth of disc                       37  29.365079  float64
# Width of disc                        41  32.539683  float64
# Thickness of disc                    10   7.936508  float64
# Weight                               27  21.428571  float64

# %%
df_tipi_espejos["Clasificada_como"] = "Categorica"
df_tipi_espejos.loc[df_tipi_espejos.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_espejos.loc[df_tipi_espejos["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_espejos.loc[df_tipi_espejos["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_espejos
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# mirrorID                            126      100.0    int64  Numerica Continua
# Context_artefacts::Site              26  20.634921   object  Numerica Discreta
# Context_artefacts::Region            13   10.31746   object  Numerica Discreta
# Category                              3   2.380952   object         Categorica
# Context_artefacts::Period             8   6.349206   object         Categorica
# Context_artefacts::Type of context    7   5.555556   object         Categorica
# Type                                  6   4.761905   object         Categorica
# Heigth of artefact                   42  33.333333  float64  Numerica Continua
# Width of artefact                    43  34.126984  float64  Numerica Continua
# Thickness of artefact                13   10.31746  float64  Numerica Discreta
# Heigth of disc                       37  29.365079  float64  Numerica Discreta
# ...

# %%
df_sierras = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/sierras.csv")
df_sierras
# Out:
#      sawID Context_artefacts::Site Context_artefacts::Region  \
# 0      208              Abu Rawash           Memphite region
# 1       72                  Abusir           Memphite region
# 2      200                  Abusir           Memphite region
# 3       17                  Abusir           Memphite region
# 4      235                  Abusir           Memphite region
# ..     ...                     ...                       ...
# 140     76                 Saqqara           Memphite region
# 141    149                 Saqqara           Memphite region
# 142    150                 Saqqara           Memphite region
# 143    244                 Saqqara           Memphite region
# 144    226                 unknown                   unknown
#
#                       Context_artefacts::Period            Type  \
# 0                        Old Kingdom, Dynasty 5               B
# 1                        Old Kingdom, Dynasty 5               B
# ...

# %%
df_tipi_sierras = pd.DataFrame([df_sierras.nunique(), df_sierras.nunique()/len(df_sierras) * 100, df_sierras.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_sierras
# Out:
#                                    Card     %_Card     Tipo
# sawID                               145      100.0    int64
# Context_artefacts::Site              10   6.896552   object
# Context_artefacts::Region             6   4.137931   object
# Context_artefacts::Period             9   6.206897   object
# Type                                  3   2.068966   object
# Context_artefacts::Type of context    6   4.137931   object
# Category                              4   2.758621   object
# Length of artefact                   20  13.793103  float64
# Width of artefact                    16  11.034483  float64
# Maximal thickness                     9   6.206897  float64
# Length of blade                      14   9.655172  float64
# Width of blade                       16  11.034483  float64
# Thickness of blade                    7   4.827586  float64
# Weight                               10   6.896552  float64

# %%
df_tipi_sierras["Clasificada_como"] = "Categorica"
df_tipi_sierras.loc[df_tipi_sierras.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_sierras.loc[df_tipi_sierras["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_sierras.loc[df_tipi_sierras["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_sierras
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# sawID                               145      100.0    int64  Numerica Continua
# Context_artefacts::Site              10   6.896552   object         Categorica
# Context_artefacts::Region             6   4.137931   object         Categorica
# Context_artefacts::Period             9   6.206897   object         Categorica
# Type                                  3   2.068966   object         Categorica
# Context_artefacts::Type of context    6   4.137931   object         Categorica
# Category                              4   2.758621   object         Categorica
# Length of artefact                   20  13.793103  float64  Numerica Discreta
# Width of artefact                    16  11.034483  float64  Numerica Discreta
# Maximal thickness                     9   6.206897  float64         Categorica
# Length of blade                      14   9.655172  float64  Numerica Discreta
# ...

# %%
df_agujas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/agujas.csv")
df_agujas
# Out:
#      needleID Context_artefacts::Site Context_artefacts::Region  \
# 0          58              Abu Rawash           Memphite region
# 1          59              Abu Rawash           Memphite region
# 2          60              Abu Rawash           Memphite region
# 3          84                  Abusir           Memphite region
# 4          61                  Abusir           Memphite region
# ..        ...                     ...                       ...
# 107       116                  Matmar  between Asiut and Abydos
# 108        55              Mostagedda  between Asiut and Abydos
# 109        66            Naga ed-Deir  between Asiut and Abydos
# 110        73             Shem Nishai                     Nubia
# 111        56    Sinki (Abydos–South)                    Abydos
#
#                      Category                      Context_artefacts::Period  \
# 0              undeterminable                         Old Kingdom, Dynasty 4
# ...

# %%
df_tipi_agujas = pd.DataFrame([df_agujas.nunique(), df_agujas.nunique()/len(df_agujas) * 100, df_agujas.dtypes]).\
    T.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"})

df_tipi_agujas
# Out:
#                                    Card     %_Card     Tipo
# needleID                            112      100.0    int64
# Context_artefacts::Site              13  11.607143   object
# Context_artefacts::Region             7       6.25   object
# Category                              2   1.785714   object
# Context_artefacts::Period             7       6.25   object
# Context_artefacts::Type of context    6   5.357143   object
# Type                                  4   3.571429   object
# Length of artefact                   52  46.428571  float64
# Maximal width                        25  22.321429  float64
# Maximal thickness                    23  20.535714  float64
# Width of head                        20  17.857143  float64
# Thickness of head                    18  16.071429  float64
# Diameter of shaft                    19  16.964286  float64
# Weight                               24  21.428571  float64

# %%
df_tipi_agujas["Clasificada_como"] = "Categorica"
df_tipi_agujas.loc[df_tipi_agujas.Card == 2, "Clasificada_como"] = "Binaria"
df_tipi_agujas.loc[df_tipi_agujas["Card"] > 10, "Clasificada_como"] ="Numerica Discreta"
df_tipi_agujas.loc[df_tipi_agujas["%_Card"] > 30, "Clasificada_como"] = "Numerica Continua"
df_tipi_agujas
# Out:
#                                    Card     %_Card     Tipo   Clasificada_como
# needleID                            112      100.0    int64  Numerica Continua
# Context_artefacts::Site              13  11.607143   object  Numerica Discreta
# Context_artefacts::Region             7       6.25   object         Categorica
# Category                              2   1.785714   object            Binaria
# Context_artefacts::Period             7       6.25   object         Categorica
# Context_artefacts::Type of context    6   5.357143   object         Categorica
# Type                                  4   3.571429   object         Categorica
# Length of artefact                   52  46.428571  float64  Numerica Continua
# Maximal width                        25  22.321429  float64  Numerica Discreta
# Maximal thickness                    23  20.535714  float64  Numerica Discreta
# Width of head                        20  17.857143  float64  Numerica Discreta
# ...

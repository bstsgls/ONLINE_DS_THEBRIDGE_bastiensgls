# %%
import pandas as pd

# %%
df_adzes = pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/adzes.xlsx")
df_adzes
# Out:
#     Context_artefacts::OK context  Context_artefacts::Order on site  adzeID  \
# 0                             AR6                                 6     562
# 1                             AR6                                 6     563
# 2                             AR7                                 7     558
# 3                             AR9                                 9      67
# 4                            AR10                                10     103
# ..                            ...                               ...     ...
# 289                           S31                                31     833
# 290                           S31                                31     834
# 291                            X5                                 5     556
# 292                            X6                                 6     631
# 293                            X6                                 6     632
#
#     Context_artefacts::Context Context_artefacts::Site  \
# 0                          AR5              Abu Rawash
# 1                          AR5              Abu Rawash
# 2                          AR1              Abu Rawash
# 3                          AR7              Abu Rawash
# 4                          AR8              Abu Rawash
# ..                         ...                     ...
# 289                        S98                 Saqqara
# 290                        S98                 Saqqara
# 291                         X4                 unknown
# 292                        X13                 unknown
# 293                        X13                 unknown
#
#     Context_artefacts::ArchaeopressFigureName  \
# 0                                          29
# 1                                          29
# 2                                          29
# 3                                          29
# 4                                          29
# ..                                        ...
# 289                                        53
# 290                                        53
# 291                                        18
# 292                Unknown-site_context-ID913
# 293                Unknown-site_context-ID913
#
#              Context_artefacts::Structure Context_artefacts::Social statusVD  \
# 0                            Mastaba F 19                            unknown
# 1                            Mastaba F 19                            unknown
# 2                            Rock Tomb H1                            unknown
# 3                            Mastaba F 21                   legal department
# 4                            Mastaba F 21                            unknown
# ..                                    ...                                ...
# 289  Lower portico ("portique inférieur")                                NaN
# 290  Lower portico ("portique inférieur")                                NaN
# 291                               unknown                               king
# 292                               unknown                               king
# 293                               unknown                               king
#
#         Context_artefacts::Part of site Context_artefacts::Owner  ...  \
# 0    Cemetery F, Old Kingdom necropolis                  unknown  ...
# 1    Cemetery F, Old Kingdom necropolis                  unknown  ...
# 2                            Cemetery H                  unknown  ...
# 3    Cemetery F, Old Kingdom necropolis                   1–kA=f  ...
# 4    Cemetery F, Old Kingdom necropolis                   1–kA=f  ...
# ..                                  ...                      ...  ...
# 289         mortuary comples of Pepy II                  Pp.y II  ...
# 290         mortuary comples of Pepy II                  Pp.y II  ...
# 291                                   –                 Wsr-kA=f  ...
# 292                                   –                 Wsr-kA=f  ...
# 293                                   –                 Wsr-kA=f  ...
#
#     Lower diameter of haft OK deben 13 g OK deben 15 g Length butt ratio  \
# 0                      NaN           NaN           NaN                 ?
# 1                      NaN           NaN           NaN               NaN
# 2                      NaN           NaN           NaN                 ?
# 3                      NaN           NaN           NaN               NaN
# 4                      NaN           NaN           NaN               NaN
# ..                     ...           ...           ...               ...
# 289                    NaN           NaN           NaN               NaN
# 290                    NaN           NaN           NaN               NaN
# 291                    NaN     38.484615     33.353333           4.97619
# 292                    NaN           NaN           NaN               NaN
# 293                    NaN           NaN           NaN               NaN
#
#       MK deben Weight Length blade ratio Context_artefacts::Present location  \
# 0          NaN    NaN                  ?                             unknown
# 1          NaN    NaN                NaN                             unknown
# 2          NaN    NaN                  ?                             unknown
# 3          NaN    NaN                NaN                             unknown
# 4          NaN    NaN                NaN                             unknown
# ..         ...    ...                ...                                 ...
# 289        NaN    NaN                NaN            Egyptian Museum, Cairo ?
# 290        NaN    NaN                NaN            Egyptian Museum, Cairo ?
# 291  18.192727  500.3           2.430233              British Museum, London
# 292        NaN    NaN                NaN              Michailidis Collection
# 293        NaN    NaN                NaN              Michailidis Collection
#
#     Inventory number                    Context_artefacts::Bibliography
# 0                NaN  Bisson de la Roque (1925, Pl. XXVI: 453ab, 455...
# 1                NaN  Bisson de la Roque (1925, Pl. XXVI: 453ab, 455...
# 2                NaN  Bisson de la Roque (1924, 61, Pl. XIII: 160); ...
# 3                NaN  Bisson de la Roque (1925, 64, Pl. XXVI: 282, 2...
# 4                NaN  Bisson de la Roque (1925, Pl. XXVI: 330: 1–2, ...
# ..               ...                                                ...
# 289              NaN                 Jéquier (1940, 48–49, Figs. 47–48)
# 290              NaN                 Jéquier (1940, 48–49, Figs. 47–48)
# 291          EA66207                    James (1961, 36–38, Pl. XII: 3)
# 292              NaN                       Kaplony (1965, 34, Taf. VII)
# 293              NaN                       Kaplony (1965, 34, Taf. VII)
#
# [294 rows x 80 columns]

# %%
print(df_adzes.columns.values)
# Out:
# ['Context_artefacts::OK context' 'Context_artefacts::Order on site'
#  'adzeID' 'Context_artefacts::Context' 'Context_artefacts::Site'
#  'Context_artefacts::ArchaeopressFigureName'
#  'Context_artefacts::Structure' 'Context_artefacts::Social statusVD'
#  'Context_artefacts::Part of site' 'Context_artefacts::Owner' 'Category'
#  'Context_artefacts::Region' 'Context_artefacts::Period' 'Class'
#  'Context_artefacts::Type of context' 'Type' 'Context_artefacts::Dating'
#  'Variant' 'Completeness' 'Context_artefacts::Quality of data'
#  'Context_artefacts::Type of pictorial documentation' 'Description' 'Haft'
#  'Material of haft' 'Thread' 'Wrapping' 'Fragments' 'Inscription'
#  'Neck section shape' 'Corrosion' 'Blade section shape' 'Bevelling'
#  'Flaring of edge' 'Edge shape' 'Length of artefact' 'Shesep'
#  'Width of artefact' 'Djeba' 'Thickness of artefact' 'Analyses' 'Method'
#  'Location of sample' 'ID of sample' 'Lower width of butt' 'Width of butt'
#  'Thickness of butt' 'Lower thickness of butt' 'Cu' 'Pb' 'As' 'Ag' 'Fe'
#  'Sb' 'Ni' 'Thickness of blade' 'Lower width of blade' 'Au' 'Co'
#  'Width of blade' 'Lower thickness of blade' 'Zn' 'Bi' 'Sn'
#  'Length of haft' 'Width of haft' 'Lower width of haft'
#  'Thickness of haft' 'Lower thickness of haft' 'S' 'Diameter of haft'
#  'Lower diameter of haft' 'OK deben 13 g' 'OK deben 15 g'
#  'Length butt ratio' 'MK deben' 'Weight' 'Length blade ratio'
#  'Context_artefacts::Present location' 'Inventory number'
#  'Context_artefacts::Bibliography']

# %%
df_adzes_new = df_adzes[['adzeID', 'Context_artefacts::Site', 'Category', 'Context_artefacts::Region', 'Context_artefacts::Period', 'Context_artefacts::Type of context',
                         'Type', 'Length of artefact', 'Width of artefact', 'Thickness of artefact', 'Lower width of butt', 'Width of butt', 'Thickness of butt',
                         'Lower thickness of butt', 'Thickness of blade', 'Lower width of blade', 'Width of blade', 'Lower thickness of blade', 'Weight']]

df_adzes_new
# Out:
#      adzeID Context_artefacts::Site                  Category  \
# 0       562              Abu Rawash               model blade
# 1       563              Abu Rawash               model blade
# 2       558              Abu Rawash               model blade
# 3        67              Abu Rawash               model blade
# 4       103              Abu Rawash               model blade
# ..      ...                     ...                       ...
# 289     833                 Saqqara  full size artefact blade
# 290     834                 Saqqara  full size artefact blade
# 291     556                 unknown  full size artefact blade
# 292     631                 unknown  full size artefact blade
# 293     632                 unknown  full size artefact blade
#
#     Context_artefacts::Region                   Context_artefacts::Period  \
# 0             Memphite region                      Old Kingdom, Dynasty 5
# 1             Memphite region                      Old Kingdom, Dynasty 5
# 2             Memphite region                      Old Kingdom, Dynasty 5
# 3             Memphite region                      Old Kingdom, Dynasty 6
# 4             Memphite region            Old Kingdom, Dynasty 5 late or 6
# ..                        ...                                         ...
# 289           Memphite region  First Intermediate Period / Middle Kingdom
# 290           Memphite region  First Intermediate Period / Middle Kingdom
# 291                   unknown                      Old Kingdom, Dynasty 5
# 292                       NaN                      Old Kingdom, Dynasty 5
# 293                       NaN                      Old Kingdom, Dynasty 5
#
#     Context_artefacts::Type of context Type  Length of artefact  \
# 0                            secondary    D                45.0
# 1                            secondary    D                 NaN
# 2                              primary    D                63.0
# 3                            secondary    D                 NaN
# 4                            secondary    D                 NaN
# ..                                 ...  ...                 ...
# 289                             temple    D                 NaN
# 290                             temple    D                 NaN
# 291                            unknown    D               209.0
# 292                            unknown    D                 NaN
# 293                            unknown    D                 NaN
#
#      Width of artefact  Thickness of artefact  Lower width of butt  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4                  NaN                    NaN                  NaN
# ..                 ...                    ...                  ...
# 289                NaN                    NaN                  NaN
# 290                NaN                    NaN                  NaN
# 291               86.0                   11.0                  NaN
# 292                NaN                    NaN                  NaN
# 293                NaN                    NaN                  NaN
#
#      Width of butt  Thickness of butt  Lower thickness of butt  \
# 0              NaN                NaN                      NaN
# 1              NaN                NaN                      NaN
# 2              NaN                NaN                      NaN
# 3              NaN                NaN                      NaN
# 4              NaN                NaN                      NaN
# ..             ...                ...                      ...
# 289            NaN                NaN                      NaN
# 290            NaN                NaN                      NaN
# 291           42.0                8.8                      NaN
# 292            NaN                NaN                      NaN
# 293            NaN                NaN                      NaN
#
#      Thickness of blade  Lower width of blade  Width of blade  \
# 0                   NaN                   NaN             NaN
# 1                   NaN                   NaN             NaN
# 2                   NaN                   NaN             NaN
# 3                   NaN                   NaN             NaN
# 4                   NaN                   NaN             NaN
# ..                  ...                   ...             ...
# 289                 NaN                   NaN             NaN
# 290                 NaN                   NaN             NaN
# 291                 2.0                   NaN            86.0
# 292                 NaN                   NaN             NaN
# 293                 NaN                   NaN             NaN
#
#      Lower thickness of blade  Weight
# 0                         NaN     NaN
# 1                         NaN     NaN
# 2                         NaN     NaN
# 3                         NaN     NaN
# 4                         NaN     NaN
# ..                        ...     ...
# 289                       NaN     NaN
# 290                       NaN     NaN
# 291                       NaN   500.3
# 292                       NaN     NaN
# 293                       NaN     NaN
#
# [294 rows x 19 columns]

# %%
df_adzes_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/azuelas.csv", index=False)

# %%
df_axes = pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/axes.xlsx")
df_axes
# Out:
#     Context_artefacts::OK context  axeID Context_artefacts::Site  \
# 0                             AR1    101              Abu Rawash
# 1                              A7    103                  Abusir
# 2                             A15    338                  Abusir
# 3                             A23    296                  Abusir
# 4                             A26    393                  Abusir
# ..                            ...    ...                     ...
# 148                           S10    177                 Saqqara
# 149                           S14    312                 Saqqara
# 150                           S20    301                 Saqqara
# 151                           S32    429                 Saqqara
# 152                            X9    297                 unknown
#
#                           Context_artefacts::Structure  \
# 0                                     Radjedef Pyramid
# 1                 Burial chamber of Pyramid Lepsius 28
# 2    princesses Khaemerernebty and Meretites, and K...
# 3                                                AC 26
# 4                                                AC 30
# ..                                                 ...
# 148                                    Pyramid of Iput
# 149                                   Tomb of Khentika
# 150      Tomb of Nypepy (Tomb XV), chamber of Shaft 32
# 151                                            unknown
# 152                                            unknown
#
#     Context_artefacts::ArchaeopressFigureName Context_artefacts::Owner  \
# 0                                 19, 29, 135                  Ra-Dd.f
# 1                                          30      most probably queen
# 2                                         NaN               KA(=j)-Htp
# 3                                          30              Wr-kAw-Ra.w
# 4                                          30            3nt-kAw=s III
# ..                                        ...                      ...
# 148                                  126, 144                    Jp.wt
# 149                                       161                   3nt-kA
# 150                Saqqara_context-ID997-1001               N(.y)–Pp.y
# 151                                       NaN                  5ps.jt?
# 152               Unknown-site_context-ID1004                      Jpj
#
#     Context_artefacts::Region                    Category  \
# 0             Memphite region    full size artefact blade
# 1             Memphite region                 model blade
# 2             Memphite region                 model blade
# 3             Memphite region                 model blade
# 4             Memphite region                 model blade
# ..                        ...                         ...
# 148           Memphite region          gilded model blade
# 149           Memphite region                 model blade
# 150           Memphite region                 model blade
# 151           Memphite region  model artefact with handle
# 152                   unknown    full size artefact blade
#
#     Context_artefacts::Period Class  ... Diameter of haft  \
# 0      Old Kingdom, Dynasty 4   axe  ...              NaN
# 1      Old Kingdom, Dynasty 5   axe  ...              NaN
# 2      Old Kingdom, Dynasty 5   axe  ...              NaN
# 3      Old Kingdom, Dynasty 5   axe  ...              NaN
# 4      Old Kingdom, Dynasty 5   axe  ...              NaN
# ..                        ...   ...  ...              ...
# 148    Old Kingdom, Dynasty 6   axe  ...              NaN
# 149    Old Kingdom, Dynasty 6   axe  ...              NaN
# 150    Old Kingdom, Dynasty 6   axe  ...              NaN
# 151                       NaN   axe  ...              NaN
# 152    Old Kingdom, Dynasty 6   axe  ...              NaN
#
#     Lower diameter of haft OK deben 13 g OK deben 15 g Heigth width ratio  \
# 0                      NaN     72.801538     63.094667              1.125
# 1                      NaN           NaN           NaN                  1
# 2                      NaN           NaN           NaN                NaN
# 3                      NaN           NaN           NaN           0.721311
# 4                      NaN      0.476923      0.413333           0.939086
# ..                     ...           ...           ...                ...
# 148                    NaN           NaN           NaN                NaN
# 149                    NaN           NaN           NaN                NaN
# 150                    NaN           NaN           NaN           0.910714
# 151                    NaN           NaN           NaN                NaN
# 152                    NaN           NaN           NaN           0.922481
#
#      Weight   MK deben Context_artefacts::Present location  \
# 0    946.42  34.415273             Egypt, IFAO excavations
# 1       NaN        NaN           Egypt, excavations of CIE
# 2       NaN        NaN                Neues Museum, Berlin
# 3       NaN        NaN           Egypt, excavations of CIE
# 4      6.20   0.225455           Egypt, excavations of CIE
# ..      ...        ...                                 ...
# 148     NaN        NaN              Egyptian Museum, Cairo
# 149     NaN        NaN                             unknown
# 150     NaN        NaN             Egypt, PCMA excavations
# 151     NaN        NaN              Egyptian Museum, Cairo
# 152     NaN        NaN      August-Kestner-Museum Hannover
#
#                     Inventory number  \
# 0                                NaN
# 1    find no. 70/J/94, reg. no. 2164
# 2           12 - Neues Museum 16 465
# 3                       10/AC26/2008
# 4             find no. 200/AC30/2014
# ..                               ...
# 148                              NaN
# 149                              NaN
# 150                          S/04/12
# 151                             1765
# 152                              NaN
#
#                        Context_artefacts::Bibliography
# 0               Valloggia (2011, 45–46, Figs. 163–164)
# 1                      Callender(2008, 127, Fig. 4.87)
# 2                  Borchardt (1907, 129–130, Abb. 109)
# 3    Krejčí (2010, 4); Krejčí – Arias Kytnarová et ...
# 4              Krejčí – Arias Kytnarová – Odler (2015)
# ..                                                 ...
# 148  Firth – Gunn (1926, 12, Fig. 6); PM III 2, 396...
# 149       James (1953, 5–6, Fig. 4); PM III 2, 508–511
# 150  Kowalska (2013, 450–452, Pl. CC, Fig. 155); We...
# 151                          Borchardt (1964, 183–186)
# 152   Loeben (2014, 323–324); Schulze – Lehmann (2014)
#
# [153 rows x 78 columns]

# %%
print(df_axes.columns.values)
# Out:
# ['Context_artefacts::OK context' 'axeID' 'Context_artefacts::Site'
#  'Context_artefacts::Structure'
#  'Context_artefacts::ArchaeopressFigureName' 'Context_artefacts::Owner'
#  'Context_artefacts::Region' 'Category' 'Context_artefacts::Period'
#  'Class' 'Context_artefacts::Type of context' 'Type'
#  'Context_artefacts::Dating' 'Variant' 'Completeness'
#  'Context_artefacts::Quality of data'
#  'Context_artefacts::Type of pictorial documentation' 'Wrapping' 'Thread'
#  'Binding' 'Number of perforations' 'Ferrules' 'Fragments' 'Inscription'
#  'Haft' 'Material of haft' 'Corrosion' 'Bevelling of edge'
#  'Flaring of edge' 'Shesep' 'Heigth of artefact' 'Djeba' 'Maximal width'
#  'Maximal thickness' 'Diameter of perforations'
#  'Lower diameter of perforations' 'Analyses' 'Method' 'Location of sample'
#  'ID of sample' 'Height of ferrule' 'Cu' 'Width of ferrule'
#  'Thickness of ferrule' 'Pb' 'Diameter of ferrule'
#  'Lower diameter of ferrule' 'As' 'Ag' 'Fe' 'Sb' 'Width of butt'
#  'Lower width of butt' 'Ni' 'Thickness of butt' 'Lower thickness of butt'
#  'Au' 'Co' 'Zn' 'Bi' 'Sn' 'Width of blade' 'Thickness of blade'
#  'Length of haft' 'Width of haft' 'Lower width of haft'
#  'Thickness of haft' 'Lower thickness of haft' 'Diameter of haft'
#  'Lower diameter of haft' 'OK deben 13 g' 'OK deben 15 g'
#  'Heigth width ratio' 'Weight' 'MK deben'
#  'Context_artefacts::Present location' 'Inventory number'
#  'Context_artefacts::Bibliography']

# %%
df_axes_new = df_axes[['axeID', 'Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 'Context_artefacts::Type of context',
                       'Type', 'Heigth of artefact', 'Maximal width', 'Maximal thickness', 'Width of blade', 'Thickness of blade', 'Weight']]

df_axes_new
# Out:
#      axeID Context_artefacts::Site Context_artefacts::Region  \
# 0      101              Abu Rawash           Memphite region
# 1      103                  Abusir           Memphite region
# 2      338                  Abusir           Memphite region
# 3      296                  Abusir           Memphite region
# 4      393                  Abusir           Memphite region
# ..     ...                     ...                       ...
# 148    177                 Saqqara           Memphite region
# 149    312                 Saqqara           Memphite region
# 150    301                 Saqqara           Memphite region
# 151    429                 Saqqara           Memphite region
# 152    297                 unknown                   unknown
#
#                        Category Context_artefacts::Period  \
# 0      full size artefact blade    Old Kingdom, Dynasty 4
# 1                   model blade    Old Kingdom, Dynasty 5
# 2                   model blade    Old Kingdom, Dynasty 5
# 3                   model blade    Old Kingdom, Dynasty 5
# 4                   model blade    Old Kingdom, Dynasty 5
# ..                          ...                       ...
# 148          gilded model blade    Old Kingdom, Dynasty 6
# 149                 model blade    Old Kingdom, Dynasty 6
# 150                 model blade    Old Kingdom, Dynasty 6
# 151  model artefact with handle                       NaN
# 152    full size artefact blade    Old Kingdom, Dynasty 6
#
#     Context_artefacts::Type of context Type  Heigth of artefact  \
# 0                     primary probably    B               180.0
# 1                            secondary    A                50.0
# 2                   secondary probably    A                 NaN
# 3                            secondary    A                44.0
# 4                            secondary    A                37.0
# ..                                 ...  ...                 ...
# 148                          secondary    A                 NaN
# 149                 secondary probably    A                 NaN
# 150                          secondary    A                51.0
# 151                            unknown    A                 NaN
# 152                            unknown    B               119.0
#
#      Maximal width  Maximal thickness  Width of blade  Thickness of blade  \
# 0            160.0                NaN             NaN                 NaN
# 1             50.0                1.0             NaN                 NaN
# 2              NaN                NaN             NaN                 NaN
# 3             61.0                2.5             NaN                 NaN
# 4             39.4                0.8             NaN                 NaN
# ..             ...                ...             ...                 ...
# 148            NaN                NaN             NaN                 NaN
# 149            NaN                NaN             NaN                 NaN
# 150           56.0                3.0             NaN                 NaN
# 151            NaN                NaN             NaN                 NaN
# 152          129.0                NaN             NaN                 NaN
#
#      Weight
# 0    946.42
# 1       NaN
# 2       NaN
# 3       NaN
# 4      6.20
# ..      ...
# 148     NaN
# 149     NaN
# 150     NaN
# 151     NaN
# 152     NaN
#
# [153 rows x 13 columns]

# %%
df_axes_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/hachas.csv", index=False)

# %%
df_chisels= pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/chisels.xlsx")
df_chisels
# Out:
#     Context_artefacts::OK context  chiselID Context_artefacts::Site  \
# 0                             AR5       174              Abu Rawash
# 1                             AR5       175              Abu Rawash
# 2                             AR7       957              Abu Rawash
# 3                             AR7       958              Abu Rawash
# 4                             AR7       959              Abu Rawash
# ..                            ...       ...                     ...
# 615                            X2       375                 unknown
# 616                            X3       377                 unknown
# 617                            X4       376                 unknown
# 618                            X6       378                 unknown
# 619                           X13       379                 unknown
#
#     Context_artefacts::Structure Context_artefacts::Owner  \
# 0                   Mastaba F 13                  unknown
# 1                   Mastaba F 13                  unknown
# 2                   Rock Tomb H1                  unknown
# 3                   Rock Tomb H1                  unknown
# 4                   Rock Tomb H1                  unknown
# ..                           ...                      ...
# 615                      unknown                  unknown
# 616                      unknown                 Wsr-kA=f
# 617                      unknown                 Wsr-kA=f
# 618                      unknown                 Wsr-kA=f
# 619                      unknown                  unknown
#
#     Context_artefacts::ArchaeopressFigureName Context_artefacts::Region  \
# 0                                          29           Memphite region
# 1                                          29           Memphite region
# 2                                          29           Memphite region
# 3                                          29           Memphite region
# 4                                          29           Memphite region
# ..                                        ...                       ...
# 615                                    20, 90                     Nubia
# 616                                        20                   unknown
# 617                                        20                   unknown
# 618                Unknown-site_context-ID913                       NaN
# 619                                       NaN                   unknown
#
#                            Category Context_artefacts::Period   Class  ...  \
# 0                       model blade    Old Kingdom, Dynasty 5  chisel  ...
# 1                       model blade    Old Kingdom, Dynasty 5  chisel  ...
# 2                       model blade    Old Kingdom, Dynasty 5  chisel  ...
# 3                       model blade    Old Kingdom, Dynasty 5  chisel  ...
# 4                       model blade    Old Kingdom, Dynasty 5  chisel  ...
# ..                              ...                       ...     ...  ...
# 615  full size artefact with handle    Old Kingdom, Dynasty 4  chisel  ...
# 616        full size artefact blade    Old Kingdom, Dynasty 5  chisel  ...
# 617        full size artefact blade    Old Kingdom, Dynasty 5  chisel  ...
# 618        full size artefact blade    Old Kingdom, Dynasty 5  chisel  ...
# 619        full size artefact blade       Old Kingdom general  chisel  ...
#
#     Maximal thickness Shaft ratio Weight Length blade width ratio  \
# 0                 NaN         NaN    NaN                      NaN
# 1                 NaN         NaN    NaN                      NaN
# 2                 NaN         NaN    NaN                        ?
# 3                 NaN         NaN    NaN                        ?
# 4                 NaN         NaN    NaN                        ?
# ..                ...         ...    ...                      ...
# 615               NaN         NaN  955.0                        ?
# 616               7.6    3.947368  273.4                       18
# 617               7.9     4.43038  398.1                21.636364
# 618               NaN         NaN    NaN                      NaN
# 619               NaN         NaN  758.0                        ?
#
#     OK deben 13 g OK deben 15 g   MK deben  \
# 0             NaN           NaN        NaN
# 1             NaN           NaN        NaN
# 2             NaN           NaN        NaN
# 3             NaN           NaN        NaN
# 4             NaN           NaN        NaN
# ..            ...           ...        ...
# 615     73.461538     63.666667  34.727273
# 616     21.030769     18.226667   9.941818
# 617     30.623077     26.540000  14.476364
# 618           NaN           NaN        NaN
# 619     58.307692     50.533333  27.563636
#
#     Context_artefacts::Present location Inventory number  \
# 0                               unknown              NaN
# 1                               unknown              NaN
# 2                               unknown              NaN
# 3                               unknown              NaN
# 4                               unknown              NaN
# ..                                  ...              ...
# 615              Egyptian Museum, Cairo         JE 68754
# 616              British Museum, London         EA 66208
# 617              British Museum, London         EA 67581
# 618              Michailidis Collection              NaN
# 619              Egyptian Museum, Cairo         JE 88422
#
#                        Context_artefacts::Bibliography
# 0    Bisson de la Roque (1925, 41, Pl. XXVI: 446a–b...
# 1    Bisson de la Roque (1925, 41, Pl. XXVI: 446a–b...
# 2    Bisson de la Roque (1924, 61, Pl. XIII: 160); ...
# 3    Bisson de la Roque (1924, 61, Pl. XIII: 160); ...
# 4    Bisson de la Roque (1924, 61, Pl. XIII: 160); ...
# ..                                                 ...
# 615                  Rowe (1938); Roth (1991, 123–124)
# 616                    James (1961, 36–38, Pl. XII: 1)
# 617                    James (1961, 36–38, Pl. XII: 2)
# 618                       Kaplony (1965, 34, Taf. VII)
# 619                       Kaplony (1965, 46, Abb. 110)
#
# [620 rows x 76 columns]

# %%
print(df_chisels.columns.values)
# Out:
# ['Context_artefacts::OK context' 'chiselID' 'Context_artefacts::Site'
#  'Context_artefacts::Structure' 'Context_artefacts::Owner'
#  'Context_artefacts::ArchaeopressFigureName' 'Context_artefacts::Region'
#  'Category' 'Context_artefacts::Period' 'Class'
#  'Context_artefacts::Type of context' 'Type' 'Context_artefacts::Dating'
#  'Variant' 'Completeness' 'Context_artefacts::Quality of data'
#  'Context_artefacts::Type of pictorial documentation' 'Description'
#  'Wrapping' 'Fragments' 'Handle' 'Tang' 'Burr' 'Inscription' 'Thread'
#  'Shoulder' 'Corrosion' 'Side' 'Section of shaft' 'Bulges' 'Bevelling'
#  'Flaring of edge' 'Edge shape' 'Length of chisel' 'Shesep' 'Djeba'
#  'Method' 'Width of tang  butt' 'Location of sample'
#  'Thickness of tang butt' 'Analyses' 'ID of sample' 'Width of butt bulge'
#  'Cu' 'Thickness of butt bulge' 'Pb' 'As' 'Width of shaft' 'Ag'
#  'Thickness of shaft' 'Fe' 'Sn' 'Maximal diameter of shaft' 'Ni'
#  'Minimal diameter of shaft' 'Au' 'Width of blade bulge' 'Co'
#  'Thickness of blade bulge' 'Zn' 'Bi' 'Thickness of blade'
#  'Width of blade' 'Rod volume' 'Maximal length width ratio'
#  'Maximal width' 'Maximal thickness' 'Shaft ratio' 'Weight'
#  'Length blade width ratio' 'OK deben 13 g' 'OK deben 15 g' 'MK deben'
#  'Context_artefacts::Present location' 'Inventory number'
#  'Context_artefacts::Bibliography']

# %%
df_chisels_new = df_chisels[['chiselID', 'Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 
                             'Context_artefacts::Type of context', 'Type', 'Length of chisel', 'Thickness of blade', 'Width of blade', 'Maximal width',
                             'Maximal thickness', 'Weight']]

df_chisels_new
# Out:
#      chiselID Context_artefacts::Site Context_artefacts::Region  \
# 0         174              Abu Rawash           Memphite region
# 1         175              Abu Rawash           Memphite region
# 2         957              Abu Rawash           Memphite region
# 3         958              Abu Rawash           Memphite region
# 4         959              Abu Rawash           Memphite region
# ..        ...                     ...                       ...
# 615       375                 unknown                     Nubia
# 616       377                 unknown                   unknown
# 617       376                 unknown                   unknown
# 618       378                 unknown                       NaN
# 619       379                 unknown                   unknown
#
#                            Category Context_artefacts::Period  \
# 0                       model blade    Old Kingdom, Dynasty 5
# 1                       model blade    Old Kingdom, Dynasty 5
# 2                       model blade    Old Kingdom, Dynasty 5
# 3                       model blade    Old Kingdom, Dynasty 5
# 4                       model blade    Old Kingdom, Dynasty 5
# ..                              ...                       ...
# 615  full size artefact with handle    Old Kingdom, Dynasty 4
# 616        full size artefact blade    Old Kingdom, Dynasty 5
# 617        full size artefact blade    Old Kingdom, Dynasty 5
# 618        full size artefact blade    Old Kingdom, Dynasty 5
# 619        full size artefact blade       Old Kingdom general
#
#     Context_artefacts::Type of context Type  Length of chisel  \
# 0                            secondary    A               NaN
# 1                            secondary    D               NaN
# 2                              primary    D              48.0
# 3                              primary    A              64.0
# 4                              primary    A              50.5
# ..                                 ...  ...               ...
# 615                            unknown    C             240.0
# 616                            unknown    E             198.0
# 617                            unknown    E             238.0
# 618                            unknown    E               NaN
# 619                            unknown    G             240.0
#
#      Thickness of blade  Width of blade  Maximal width  Maximal thickness  \
# 0                   NaN             NaN            NaN                NaN
# 1                   NaN             NaN            NaN                NaN
# 2                   NaN             NaN            NaN                NaN
# 3                   NaN             NaN            NaN                NaN
# 4                   NaN             NaN            NaN                NaN
# ..                  ...             ...            ...                ...
# 615                 NaN             NaN            NaN                NaN
# 616                 2.0            11.0           30.0                7.6
# 617                 NaN            11.0           35.0                7.9
# 618                 NaN             NaN            NaN                NaN
# 619                 NaN             NaN            NaN                NaN
#
#      Weight
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 615   955.0
# 616   273.4
# 617   398.1
# 618     NaN
# 619   758.0
#
# [620 rows x 13 columns]

# %%
df_chisels_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/cinceles.csv", index=False)

# %%
df_mirrors = pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/mirrors.xlsx")
df_mirrors
# Out:
#     Context_artefacts::OK context  mirrorID Context_artefacts::Site  \
# 0                            Ay14        60                  Abydos
# 1                            Ay18       208                  Abydos
# 2                            Ay19       304                  Abydos
# 3                             Ad2        52                 Adindan
# 4                             An1       273                   Aniba
# ..                            ...       ...                     ...
# 121                           X18       300                 unknown
# 122                           X19       301                 unknown
# 123                           X21       303                 unknown
# 124                           ZM1       260      Zawiyet el-Mayitin
# 125                           ZM2       259      Zawiyet el-Mayitin
#
#      Context_artefacts::Structure Context_artefacts::ArchaeopressFigureName  \
# 0                  Tomb 747, A.09                                       NaN
# 1    building west of structure H                       Abydos_context-Ay18
# 2                        Tomb 898                                       NaN
# 3                     Grave T 155                                   68, 187
# 4                   Grave N 958 b                                        68
# ..                            ...                                       ...
# 121                       unknown                                       193
# 122                       unknown                                       193
# 123                       unknown                                       193
# 124                     Tomb RS 1                                   65, 187
# 125                     Tomb RS 5                                        65
#
#     Context_artefacts::Owner     Context_artefacts::Region  \
# 0                    unknown                        Abydos
# 1                 settlement                        Abydos
# 2                    unknown                        Abydos
# 3                    unknown                         Nubia
# 4                    unknown                         Nubia
# ..                       ...                           ...
# 121                    WHA.t                       unknown
# 122          Nfr-jwn(.tjw)\n                       unknown
# 123                    4pt.t                       unknown
# 124                  unknown  between Fayum and Beni Hasan
# 125               Nfr.t-jj.t  between Fayum and Beni Hasan
#
#                      Category                      Context_artefacts::Period  \
# 0                 model blade  Old Kingdom, late / First Intermediate period
# 1    full size artefact blade  Old Kingdom, late / First Intermediate period
# 2    full size artefact blade                         Old Kingdom, Dynasty 5
# 3    full size artefact blade                            Old Kingdom general
# 4    full size artefact blade                         Old Kingdom, Dynasty 6
# ..                        ...                                            ...
# 121  full size artefact blade                         Old Kingdom, Dynasty 6
# 122  full size artefact blade                         Old Kingdom, Dynasty 6
# 123  full size artefact blade                         Old Kingdom, Dynasty 6
# 124  full size artefact blade                         Old Kingdom, Dynasty 6
# 125  full size artefact blade                         Old Kingdom, Dynasty 6
#
#       Class  ...   Disc area Complete height widht ratio Weight  \
# 0    mirror  ...         NaN                           ?    NaN
# 1    mirror  ...         NaN                         NaN    NaN
# 2    mirror  ...         NaN                         NaN    NaN
# 3    mirror  ...         NaN                         NaN    NaN
# 4    mirror  ...    0.000000                    1.090909    NaN
# ..      ...  ...         ...                         ...    ...
# 121  mirror  ...  163.755517                    1.093333    NaN
# 122  mirror  ...         NaN                         NaN    NaN
# 123  mirror  ...         NaN                         NaN    NaN
# 124  mirror  ...  194.621665                    0.861905  328.6
# 125  mirror  ...  192.807395                    1.053892  326.9
#
#     Disc height width ratio OK deben 13 g OK deben 15 g   MK deben  \
# 0                       NaN           NaN           NaN        NaN
# 1                       NaN           NaN           NaN        NaN
# 2                       NaN           NaN           NaN        NaN
# 3                       NaN           NaN           NaN        NaN
# 4                         0           NaN           NaN        NaN
# ..                      ...           ...           ...        ...
# 121                       ?           NaN           NaN        NaN
# 122                     NaN           NaN           NaN        NaN
# 123                     NaN           NaN           NaN        NaN
# 124                       ?     25.276923     21.906667  11.949091
# 125                       ?     25.146154     21.793333  11.887273
#
#     Context_artefacts::Present location    Inventory number  \
# 0                Egyptian Museum, Cairo          JdE  41375
# 1       British Museum, London; unknown                 NaN
# 2                British Museum, London             EA57900
# 3           Oriental Institute, Chicago                 NaN
# 4                               unknown                 NaN
# ..                                  ...                 ...
# 121                       Louvre, Paris              E 3307
# 122                           Liverpool        Univ. E 1510
# 123                          Manchester    number not known
# 124                       Louvre, Paris             E.11457
# 125                       Louvre, Paris  E. 11470 = AF.6502
#
#                        Context_artefacts::Bibliography
# 0    Lilyquist (1979, 12, Fig. 20); Garstang (1909,...
# 1    Petrie (1903, 32, Pl. XXII: 1–9); Davies (1987...
# 2                        Lilyquist (1979, 12, Fig. 21)
# 3             Williams (1989, 122, 128, Fig. 71: b, j)
# 4    Steindorff (1935, 113, 115, 191, Taf. 69, 70: ...
# ..                                                 ...
# 121                      Lilyquist (1979, 14, Fig. 16)
# 122                      Lilyquist (1979, 14, Fig. 17)
# 123                      Lilyquist (1979, 14, Fig. 19)
# 124  Piacentini (1993, 67); Vandier d’Abbadie (1972...
# 125  Michel (1972); Piacentini (1993, 68); Vandier ...
#
# [126 rows x 76 columns]

# %%
print(df_mirrors.columns.values)
# Out:
# ['Context_artefacts::OK context' 'mirrorID' 'Context_artefacts::Site'
#  'Context_artefacts::Structure'
#  'Context_artefacts::ArchaeopressFigureName' 'Context_artefacts::Owner'
#  'Context_artefacts::Region' 'Category' 'Context_artefacts::Period'
#  'Class' 'Context_artefacts::Type of context' 'Type' 'Variant'
#  'Context_artefacts::Dating' 'Completeness'
#  'Context_artefacts::Quality of data'
#  'Context_artefacts::Type of pictorial documentation' 'Shape of disc'
#  'Rivet holes' 'Tang' 'Type of tang' 'Fragments' 'Corrosion' 'Handle'
#  'Material of handle' 'Wrapping' 'Inscription' 'Analyses'
#  'Heigth of artefact' 'Width of artefact' 'Thickness of artefact' 'Method'
#  'Heigth of disc' 'Location of sample' 'Width of disc' 'ID of sample'
#  'Shesep disc height' 'Shesep disc width' 'Cu' 'Djeba disc height'
#  'Djeba disc width' 'Pb' 'Thickness of disc' 'Lower thickness of disc'
#  'As' 'Ag' 'Length of tang' 'Fe' 'Lower width of tang' 'Width of tang'
#  'Lower thickness of tang' 'Thickness of tang' 'Sb' 'Ni' 'Au' 'Co' 'Zn'
#  'Length of handle' 'Bi' 'Width of handle' 'Lower width of handle' 'Sn'
#  'Thickness of handle' 'Lower thickness of handle' 'Diameter of handle'
#  'Lower diameter of handle' 'Disc area' 'Complete height widht ratio'
#  'Weight' 'Disc height width ratio' 'OK deben 13 g' 'OK deben 15 g'
#  'MK deben' 'Context_artefacts::Present location' 'Inventory number'
#  'Context_artefacts::Bibliography']

# %%
df_mirrors_new = df_mirrors[['mirrorID', 'Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period',
                             'Context_artefacts::Type of context', 'Type', 'Heigth of artefact', 'Width of artefact', 'Thickness of artefact', 'Heigth of disc',
                             'Width of disc', 'Thickness of disc', 'Weight']]

df_mirrors_new
# Out:
#      mirrorID Context_artefacts::Site     Context_artefacts::Region  \
# 0          60                  Abydos                        Abydos
# 1         208                  Abydos                        Abydos
# 2         304                  Abydos                        Abydos
# 3          52                 Adindan                         Nubia
# 4         273                   Aniba                         Nubia
# ..        ...                     ...                           ...
# 121       300                 unknown                       unknown
# 122       301                 unknown                       unknown
# 123       303                 unknown                       unknown
# 124       260      Zawiyet el-Mayitin  between Fayum and Beni Hasan
# 125       259      Zawiyet el-Mayitin  between Fayum and Beni Hasan
#
#                      Category                      Context_artefacts::Period  \
# 0                 model blade  Old Kingdom, late / First Intermediate period
# 1    full size artefact blade  Old Kingdom, late / First Intermediate period
# 2    full size artefact blade                         Old Kingdom, Dynasty 5
# 3    full size artefact blade                            Old Kingdom general
# 4    full size artefact blade                         Old Kingdom, Dynasty 6
# ..                        ...                                            ...
# 121  full size artefact blade                         Old Kingdom, Dynasty 6
# 122  full size artefact blade                         Old Kingdom, Dynasty 6
# 123  full size artefact blade                         Old Kingdom, Dynasty 6
# 124  full size artefact blade                         Old Kingdom, Dynasty 6
# 125  full size artefact blade                         Old Kingdom, Dynasty 6
#
#     Context_artefacts::Type of context Type  Heigth of artefact  \
# 0                              primary    C                 0.0
# 1                           settlement    C                 NaN
# 2                            secondary    E                 NaN
# 3                              primary    B                 NaN
# 4                              primary    C               240.0
# ..                                 ...  ...                 ...
# 121                            unknown    C               164.0
# 122                            unknown    C                 NaN
# 123                            unknown    C                 NaN
# 124                            unknown    C               181.0
# 125                            unknown    D               176.0
#
#      Width of artefact  Thickness of artefact  Heigth of disc  Width of disc  \
# 0                  NaN                    NaN             NaN            NaN
# 1                  NaN                    NaN             NaN            NaN
# 2                  NaN                    NaN             NaN            NaN
# 3                  NaN                    NaN             NaN            NaN
# 4                220.0                    NaN             NaN          220.0
# ..                 ...                    ...             ...            ...
# 121              150.0                    4.5           139.0          150.0
# 122                NaN                    NaN             NaN            NaN
# 123                NaN                    NaN             NaN            NaN
# 124              210.0                    6.0           118.0          210.0
# 125              167.0                    3.5           147.0          167.0
#
#      Thickness of disc  Weight
# 0                  NaN     NaN
# 1                  NaN     NaN
# 2                  NaN     NaN
# 3                  NaN     NaN
# 4                  NaN     NaN
# ..                 ...     ...
# 121                4.5     NaN
# 122                NaN     NaN
# 123                NaN     NaN
# 124                4.4   328.6
# 125                NaN   326.9
#
# [126 rows x 14 columns]

# %%
df_mirrors_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/espejos.csv", index=False)

# %%
df_saws = pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/saws.xlsx")
df_saws
# Out:
#      sawID Context_artefacts::OK context Context_artefacts::Site  \
# 0      208                           AR7              Abu Rawash
# 1       72                            A2                  Abusir
# 2      200                           A15                  Abusir
# 3       17                           A19                  Abusir
# 4      235                           A26                  Abusir
# ..     ...                           ...                     ...
# 140     76                            S9                 Saqqara
# 141    149                           S14                 Saqqara
# 142    150                           S14                 Saqqara
# 143    244                           S31                 Saqqara
# 144    226                           X11                 unknown
#
#                           Context_artefacts::Structure  \
# 0                                         Rock Tomb H1
# 1                 Burial chamber of Pyramid Lepsius 24
# 2    princesses Khaemerernebty and Meretites, and K...
# 3                                         Lepsius 25/1
# 4                                                AC 30
# ..                                                 ...
# 140                       Tomb of Neferseshemra- Shesi
# 141                                   Tomb of Khentika
# 142                                   Tomb of Khentika
# 143               Lower portico ("portique inférieur")
# 144                                            unknown
#
#     Context_artefacts::Owner Context_artefacts::ArchaeopressFigureName  \
# 0                    unknown                                        29
# 1        most probably queen                                        30
# 2                 KA(=j)-Htp                                       NaN
# 3                     1A-nbw                                        30
# 4              3nt-kAw=s III                                        30
# ..                       ...                                       ...
# 140         Nfr-sSm-ra - 4si                              50, 126, 143
# 141                   3nt-kA                                       161
# 142                   3nt-kA                                       161
# 143                  Pp.y II                                        53
# 144             Ntr-jr-kA-ra                Unknown-site_context-ID480
#
#     Context_artefacts::Region Class  \
# 0             Memphite region   saw
# 1             Memphite region   saw
# 2             Memphite region   saw
# 3             Memphite region   saw
# 4             Memphite region   saw
# ..                        ...   ...
# 140           Memphite region   saw
# 141           Memphite region   saw
# 142           Memphite region   saw
# 143           Memphite region   saw
# 144                   unknown   saw
#
#                       Context_artefacts::Period            Type  ...  Sn  \
# 0                        Old Kingdom, Dynasty 5               B  ... NaN
# 1                        Old Kingdom, Dynasty 5               B  ... NaN
# 2                        Old Kingdom, Dynasty 5               B  ... NaN
# 3                        Old Kingdom, Dynasty 5               B  ... NaN
# 4                        Old Kingdom, Dynasty 5               B  ... NaN
# ..                                          ...             ...  ...  ..
# 140                      Old Kingdom, Dynasty 6               B  ... NaN
# 141                      Old Kingdom, Dynasty 6               B  ... NaN
# 142                      Old Kingdom, Dynasty 6               A  ... NaN
# 143  First Intermediate Period / Middle Kingdom  undeterminable  ... NaN
# 144                   First Intermediate period               A  ... NaN
#
#     OK deben 13 g OK deben 15 g  MK deben Weight Complete length width ratio  \
# 0             NaN           NaN       NaN    NaN                           ?
# 1             NaN           NaN       NaN    NaN                    7.619048
# 2             NaN           NaN       NaN    NaN                         NaN
# 3             NaN           NaN       NaN    NaN                      7.1875
# 4        0.430769      0.373333  0.203636    5.6                    7.733333
# ..            ...           ...       ...    ...                         ...
# 140           NaN           NaN       NaN    NaN                         NaN
# 141           NaN           NaN       NaN    NaN                         NaN
# 142           NaN           NaN       NaN    NaN                         NaN
# 143           NaN           NaN       NaN    NaN                         NaN
# 144           NaN           NaN       NaN    NaN                         NaN
#
#     Blade length width ratio                   Inventory number  \
# 0                        NaN                                NaN
# 1                   6.904762   find no. 66/J/94c, reg. no. 2164
# 2                        NaN      8 - Neues Museum 16472, 16497
# 3                   5.937500                          75/N/2003
# 4                   6.600000             find no. 253/AC30/2014
# ..                       ...                                ...
# 140                      NaN                                NaN
# 141                      NaN                                NaN
# 142                      NaN                                NaN
# 143                      NaN                                NaN
# 144                      NaN                            EA66205
#
#     Context_artefacts::Present location  \
# 0                               unknown
# 1             Egypt, excavations of CIE
# 2                  Neues Museum, Berlin
# 3             Egypt, excavations of CIE
# 4             Egypt, excavations of CIE
# ..                                  ...
# 140              Egyptian Museum, Cairo
# 141                             unknown
# 142                             unknown
# 143            Egyptian Museum, Cairo ?
# 144              British Museum, London
#
#                        Context_artefacts::Bibliography
# 0    Bisson de la Roque (1924, 61, Pl. XIII: 160); ...
# 1    Callender (2008, 123–125, Figs. 4.81b, 4.81c; ...
# 2                  Borchardt (1907, 129–130, Abb. 109)
# 3            Krejčí (2008a, 189, Fig. 5.73b, Pl. VIII)
# 4              Krejčí – Arias Kytnarová – Odler (2015)
# ..                                                 ...
# 140  Firth – Gunn (1926, 19, Fig. 14); PM III 2, 51...
# 141       James (1953, 5–6, Fig. 4); PM III 2, 508–511
# 142       James (1953, 5–6, Fig. 4); PM III 2, 508–511
# 143                 Jéquier (1940, 48–49, Figs. 47–48)
# 144  James (1961, 36–38, Pl. XII: 4); Kaplony (1965...
#
# [145 rows x 66 columns]

# %%
print(df_saws.columns.values)
# Out:
# ['sawID' 'Context_artefacts::OK context' 'Context_artefacts::Site'
#  'Context_artefacts::Structure' 'Context_artefacts::Owner'
#  'Context_artefacts::ArchaeopressFigureName' 'Context_artefacts::Region'
#  'Class' 'Context_artefacts::Period' 'Type' 'Variant'
#  'Context_artefacts::Type of context' 'Context_artefacts::Dating'
#  'Category' 'Completeness'
#  'Context_artefacts::Type of pictorial documentation' 'Handle'
#  'Type of handle' 'Tang' 'Type of tang' 'Thread' 'Fragments' 'Inscription'
#  'Corrosion' 'Teeth' 'Wrapping' 'Length of artefact' 'Analyses' 'Shesep'
#  'Method' 'Djeba' 'Location of sample' 'Width of artefact'
#  'Maximal thickness' 'ID of sample' 'Length of handle' 'Width of handle'
#  'Cu' 'Thickness of handle' 'Pb' 'Diameter of handle' 'As' 'Ag'
#  'Length of tang' 'Fe' 'Width of tang' 'Sb' 'Thickness of tang' 'Ni' 'Au'
#  'Length of blade' 'Co' 'Width of blade' 'Zn' 'Thickness of blade' 'Bi'
#  'Sn' 'OK deben 13 g' 'OK deben 15 g' 'MK deben' 'Weight'
#  'Complete length width ratio' 'Blade length width ratio'
#  'Inventory number' 'Context_artefacts::Present location'
#  'Context_artefacts::Bibliography']

# %%
df_saws_new = df_saws[['sawID', 'Context_artefacts::Site', 'Context_artefacts::Region', 'Context_artefacts::Period', 'Type', 'Context_artefacts::Type of context',
                       'Category', 'Length of artefact', 'Width of artefact', 'Maximal thickness','Length of blade', 'Width of blade', 'Thickness of blade', 'Weight']]

df_saws_new
# Out:
#      sawID Context_artefacts::Site Context_artefacts::Region  \
# 0      208              Abu Rawash           Memphite region
# 1       72                  Abusir           Memphite region
# 2      200                  Abusir           Memphite region
# 3       17                  Abusir           Memphite region
# 4      235                  Abusir           Memphite region
# ..     ...                     ...                       ...
# 140     76                 Saqqara           Memphite region
# 141    149                 Saqqara           Memphite region
# 142    150                 Saqqara           Memphite region
# 143    244                 Saqqara           Memphite region
# 144    226                 unknown                   unknown
#
#                       Context_artefacts::Period            Type  \
# 0                        Old Kingdom, Dynasty 5               B
# 1                        Old Kingdom, Dynasty 5               B
# 2                        Old Kingdom, Dynasty 5               B
# 3                        Old Kingdom, Dynasty 5               B
# 4                        Old Kingdom, Dynasty 5               B
# ..                                          ...             ...
# 140                      Old Kingdom, Dynasty 6               B
# 141                      Old Kingdom, Dynasty 6               B
# 142                      Old Kingdom, Dynasty 6               A
# 143  First Intermediate Period / Middle Kingdom  undeterminable
# 144                   First Intermediate period               A
#
#     Context_artefacts::Type of context                  Category  \
# 0                              primary               model blade
# 1                            secondary               model blade
# 2                   secondary probably               model blade
# 3                            secondary               model blade
# 4                            secondary               model blade
# ..                                 ...                       ...
# 140                          secondary        gilded model blade
# 141                 secondary probably               model blade
# 142                 secondary probably               model blade
# 143                             temple  full size artefact blade
# 144                            unknown  full size artefact blade
#
#      Length of artefact  Width of artefact  Maximal thickness  \
# 0                  80.0                NaN                NaN
# 1                 160.0               21.0                NaN
# 2                   NaN                NaN                NaN
# 3                 115.0               16.0                NaN
# 4                 116.0               15.0                2.2
# ..                  ...                ...                ...
# 140                 NaN                NaN                NaN
# 141                 NaN                NaN                NaN
# 142                 NaN                NaN                NaN
# 143                 NaN                NaN                NaN
# 144                 NaN                NaN                NaN
#
#      Length of blade  Width of blade  Thickness of blade  Weight
# 0                NaN             NaN                 NaN     NaN
# 1              145.0            21.0                 NaN     NaN
# 2                NaN             NaN                 NaN     NaN
# 3               95.0            16.0                 1.0     NaN
# 4               99.0            15.0                 1.0     5.6
# ..               ...             ...                 ...     ...
# 140              NaN             NaN                 NaN     NaN
# 141              NaN             NaN                 NaN     NaN
# 142              NaN             NaN                 NaN     NaN
# 143              NaN             NaN                 NaN     NaN
# 144              NaN             NaN                 NaN     NaN
#
# [145 rows x 14 columns]

# %%
df_saws_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/sierras.csv", index=False)

# %%
df_needles = pd.read_excel("/Users/bastiensegalas/Desktop/EDA/data/needles.xlsx")
df_needles
# Out:
#      needleID Context_artefacts::OK context  \
# 0          58                           AR2
# 1          59                           AR3
# 2          60                           AR4
# 3          84                            A2
# 4          61                            A6
# ..        ...                           ...
# 107       116                           Mt8
# 108        55                           Ms8
# 109        66                           ND1
# 110        73                          ShN1
# 111        56                          Snk1
#
#     Context_artefacts::ArchaeopressFigureName Context_artefacts::Site  \
# 0                                           –              Abu Rawash
# 1                                           –              Abu Rawash
# 2                                           –              Abu Rawash
# 3                                          30                  Abusir
# 4                                          30                  Abusir
# ..                                        ...                     ...
# 107                                       NaN                  Matmar
# 108                                        56              Mostagedda
# 109                                         –            Naga ed-Deir
# 110                                       NaN             Shem Nishai
# 111                                         –    Sinki (Abydos–South)
#
#                           Context_artefacts::Structure  \
# 0                           Radjedef satellite Pyramid
# 1                           Radjedef satellite Pyramid
# 2                                           settlement
# 3                 Burial chamber of Pyramid Lepsius 24
# 4                 Burial chamber of Pyramid Lepsius 28
# ..                                                 ...
# 107                                          Grave 813
# 108                                       Grave 10 000
# 109                                         Grave 4742
# 110                                          Grave 546
# 111  burial in layer of refuse near the pyramid in ...
#
#     Context_artefacts::Owner Context_artefacts::Region  \
# 0                    Ra-Dd.f           Memphite region
# 1                    Ra-Dd.f           Memphite region
# 2                 settlement           Memphite region
# 3        most probably queen           Memphite region
# 4        most probably queen           Memphite region
# ..                       ...                       ...
# 107                  unknown  between Asiut and Abydos
# 108                  unknown  between Asiut and Abydos
# 109                  unknown  between Asiut and Abydos
# 110                  unknown                     Nubia
# 111                  unknown                    Abydos
#
#                      Category                      Context_artefacts::Period  \
# 0              undeterminable                         Old Kingdom, Dynasty 4
# 1              undeterminable                         Old Kingdom, Dynasty 4
# 2              undeterminable                         Old Kingdom, Dynasty 4
# 3    full size artefact blade                         Old Kingdom, Dynasty 5
# 4    full size artefact blade                         Old Kingdom, Dynasty 5
# ..                        ...                                            ...
# 107            undeterminable                         Old Kingdom, Dynasty 6
# 108  full size artefact blade                         Old Kingdom, Dynasty 6
# 109            undeterminable  Old Kingdom, late / First Intermediate period
# 110  full size artefact blade                            Old Kingdom general
# 111            undeterminable                         Old Kingdom, Dynasty 6
#
#       Class  ...  Co  Zn  Bi OK deben 13 g OK deben 15 g MK deben Weight  \
# 0    needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 1    needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 2    needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 3    needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 4    needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# ..      ...  ...  ..  ..  ..           ...           ...      ...    ...
# 107  needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 108  needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 109  needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 110  needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
# 111  needle  ... NaN NaN NaN           NaN           NaN      NaN    NaN
#
#     Context_artefacts::Present location  \
# 0               Egypt, IFAO excavations
# 1               Egypt, IFAO excavations
# 2               Egypt, IFAO excavations
# 3             Egypt, excavations of CIE
# 4             Egypt, excavations of CIE
# ..                                  ...
# 107                                 NaN
# 108                             unknown
# 109                             unknown
# 110                             unknown
# 111                             unknown
#
#                        Context_artefacts::Bibliography        Inventory number
# 0    Valloggia (2011, 63); Marchand (2009, 73, Fig. 3)                     NaN
# 1    Valloggia (2011, 64); Marchand (2009, 73, Fig. 3)                     NaN
# 2                    Valloggia (2011, 72–73, Fig. 274)                     NaN
# 3    Callender (2008, 123–125, Figs. 4.81b, 4.81c; ...  66/J/94, reg. no. 2164
# 4                                Callender (2008, 126)              66/J/1994c
# ..                                                 ...                     ...
# 107                             Brunton (1948, 32, 52)                     NaN
# 108                    Brunton (1937, 98, Pl. LXI: 16)                     NaN
# 109                                    Mace (1909, 64)                     NaN
# 110                      Reisner (1910, 275, Fig. 232)                     NaN
# 111                         Dreyer – Swelim (1982, 93)                     NaN
#
# [112 rows x 58 columns]

# %%
print(df_needles.columns.values)
# Out:
# ['needleID' 'Context_artefacts::OK context'
#  'Context_artefacts::ArchaeopressFigureName' 'Context_artefacts::Site'
#  'Context_artefacts::Structure' 'Context_artefacts::Owner'
#  'Context_artefacts::Region' 'Category' 'Context_artefacts::Period'
#  'Class' 'Context_artefacts::Type of context' 'Type'
#  'Context_artefacts::Dating' 'Variant' 'Completeness'
#  'Context_artefacts::Type of pictorial documentation'
#  'Context_artefacts::Quality of data'
#  'Context_artefacts::Type of structure' 'Description' 'Shape of head'
#  'Section of shaft' 'Wrapping' 'Thread' 'Fragments' 'Inscription'
#  'Corrosion' 'Shesep' 'Length of artefact' 'Analyses' 'Djeba'
#  'Maximal width' 'Maximal thickness' 'Method' 'Location of sample'
#  'Width of head' 'Thickness of head' 'ID of sample' 'Diameter of shaft'
#  'Lower diameter of shaft' 'Picture 4' 'Cu' 'Pb' 'As' 'Ag' 'Fe' 'Sb' 'Ni'
#  'Au' 'Co' 'Zn' 'Bi' 'OK deben 13 g' 'OK deben 15 g' 'MK deben' 'Weight'
#  'Context_artefacts::Present location' 'Context_artefacts::Bibliography'
#  'Inventory number']

# %%
df_needles_new = df_needles[['needleID', 'Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period',
                             'Context_artefacts::Type of context', 'Type', 'Length of artefact', 'Maximal width', 'Maximal thickness', 'Width of head', 
                             'Thickness of head', 'Diameter of shaft', 'Weight']]

df_needles_new
# Out:
#      needleID Context_artefacts::Site Context_artefacts::Region  \
# 0          58              Abu Rawash           Memphite region
# 1          59              Abu Rawash           Memphite region
# 2          60              Abu Rawash           Memphite region
# 3          84                  Abusir           Memphite region
# 4          61                  Abusir           Memphite region
# ..        ...                     ...                       ...
# 107       116                  Matmar  between Asiut and Abydos
# 108        55              Mostagedda  between Asiut and Abydos
# 109        66            Naga ed-Deir  between Asiut and Abydos
# 110        73             Shem Nishai                     Nubia
# 111        56    Sinki (Abydos–South)                    Abydos
#
#                      Category                      Context_artefacts::Period  \
# 0              undeterminable                         Old Kingdom, Dynasty 4
# 1              undeterminable                         Old Kingdom, Dynasty 4
# 2              undeterminable                         Old Kingdom, Dynasty 4
# 3    full size artefact blade                         Old Kingdom, Dynasty 5
# 4    full size artefact blade                         Old Kingdom, Dynasty 5
# ..                        ...                                            ...
# 107            undeterminable                         Old Kingdom, Dynasty 6
# 108  full size artefact blade                         Old Kingdom, Dynasty 6
# 109            undeterminable  Old Kingdom, late / First Intermediate period
# 110  full size artefact blade                            Old Kingdom general
# 111            undeterminable                         Old Kingdom, Dynasty 6
#
#     Context_artefacts::Type of context            Type  Length of artefact  \
# 0                            secondary  undeterminable                 NaN
# 1                   secondary probably  undeterminable                 NaN
# 2                           settlement  undeterminable                 NaN
# 3                            secondary               B                73.0
# 4                            secondary               B                73.0
# ..                                 ...             ...                 ...
# 107                            primary  undeterminable                 NaN
# 108                   primary probably               B                 NaN
# 109                          secondary  undeterminable                 NaN
# 110                   primary probably  undeterminable                 NaN
# 111                   primary probably  undeterminable                 NaN
#
#      Maximal width  Maximal thickness  Width of head  Thickness of head  \
# 0              NaN                NaN            NaN                NaN
# 1              NaN                NaN            NaN                NaN
# 2              NaN                NaN            NaN                NaN
# 3              4.0                2.0            4.0                NaN
# 4              4.0                3.0            4.0                NaN
# ..             ...                ...            ...                ...
# 107            NaN                NaN            NaN                NaN
# 108            NaN                NaN            NaN                NaN
# 109            NaN                NaN            NaN                NaN
# 110            NaN                NaN            NaN                NaN
# 111            NaN                NaN            NaN                NaN
#
#      Diameter of shaft  Weight
# 0                  NaN     NaN
# 1                  NaN     NaN
# 2                  NaN     NaN
# 3                  NaN     NaN
# 4                  3.0     NaN
# ..                 ...     ...
# 107                NaN     NaN
# 108                NaN     NaN
# 109                NaN     NaN
# 110                NaN     NaN
# 111                NaN     NaN
#
# [112 rows x 14 columns]

# %%
df_needles_new.to_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/agujas.csv", index=False)

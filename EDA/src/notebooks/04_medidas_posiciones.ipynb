# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
def plot_multiple_boxplots(df, columns, dim_matriz_visual = 2):
    num_cols = len(columns)
    num_rows = num_cols // dim_matriz_visual + num_cols % dim_matriz_visual
    fig, axes = plt.subplots(num_rows, dim_matriz_visual, figsize=(12, 6 * num_rows))
    axes = axes.flatten()

    for i, column in enumerate(columns):
        if df[column].dtype in ['int64', 'float64']:
            sns.boxplot(data=df, x=column, ax=axes[i])
            axes[i].set_title(column)

    # Ocultar ejes vacíos
    for j in range(i+1, num_rows * 2):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

def plot_boxplot_grouped(df, column_to_plot, group_column):
    if df[column_to_plot].dtype in ['int64', 'float64'] and df[group_column].dtype in ['object', 'category']:
        sns.boxplot(data=df, x=group_column, y=column_to_plot)
        plt.show()

# %%
df_azuelas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/azuelas.csv")
df_hachas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/hachas.csv")
df_cinceles = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/cinceles.csv")
df_espejos = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/espejos.csv")
df_sierras = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/sierras.csv")
df_agujas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/agujas.csv")

# %%
num_azuelas = ['Length of artefact', 'Width of artefact', 'Thickness of artefact', 'Width of butt', 'Thickness of butt', 'Thickness of blade',
               'Width of blade', 'Weight']

plot_multiple_boxplots(df_azuelas, num_azuelas)

# %%
num_hachas = ['Heigth of artefact', 'Maximal width', 'Maximal thickness', 'Width of blade', 'Thickness of blade', 'Weight']

plot_multiple_boxplots(df_hachas, num_hachas)

# %%
num_cinceles = ['Length of chisel', 'Thickness of blade', 'Width of blade', 'Maximal width', 'Maximal thickness', 'Weight']

plot_multiple_boxplots(df_cinceles, num_cinceles)

# %%
num_espejos = ['Heigth of artefact', 'Width of artefact', 'Thickness of artefact', 'Heigth of disc', 'Width of disc',
               'Thickness of disc', 'Weight']

plot_multiple_boxplots(df_espejos, num_espejos)

# %%
num_sierras = ['Length of artefact', 'Width of artefact', 'Maximal thickness', 'Length of blade', 'Width of blade', 'Thickness of blade']

plot_multiple_boxplots(df_sierras, num_sierras)

# %%
num_agujas = ['Length of artefact', 'Maximal width', 'Maximal thickness', 'Width of head', 'Thickness of head', 'Diameter of shaft',
              'Weight']

plot_multiple_boxplots(df_agujas, num_agujas)

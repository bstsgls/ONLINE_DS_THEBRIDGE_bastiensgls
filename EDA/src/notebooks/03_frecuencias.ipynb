# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
def distrib_cat(df, columnas_categoricas, relativa=False, mostrar_valores=False):
    num_columnas = len(columnas_categoricas)
    num_filas = (num_columnas // 2) + (num_columnas % 2)

    fig, axes = plt.subplots(num_filas, 2, figsize=(15, 5 * num_filas))
    axes = axes.flatten() 

    for i, col in enumerate(columnas_categoricas):
        ax = axes[i]
        if relativa:
            total = df[col].value_counts().sum()
            serie = df[col].value_counts().apply(lambda x: x / total)
            sns.barplot(x=serie.index, y=serie, ax=ax, palette='viridis', hue = serie.index, legend = False)
            ax.set_ylabel('Frecuencia Relativa')
        else:
            serie = df[col].value_counts()
            sns.barplot(x=serie.index, y=serie, ax=ax, palette='viridis', hue = serie.index, legend = False)
            ax.set_ylabel('Frecuencia')

        ax.set_title(f'Distribución de {col}')
        ax.set_xlabel('')
        ax.tick_params(axis='x', rotation=45)

        if mostrar_valores:
            for p in ax.patches:
                height = p.get_height()
                ax.annotate(f'{height:.2f}', (p.get_x() + p.get_width() / 2., height), 
                            ha='center', va='center', xytext=(0, 9), textcoords='offset points')

    for j in range(i + 1, num_filas * 2):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

# %%
df_azuelas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/azuelas.csv")
df_hachas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/hachas.csv")
df_cinceles = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/cinceles.csv")
df_espejos = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/espejos.csv")
df_sierras = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/sierras.csv")
df_agujas = pd.read_csv("/Users/bastiensegalas/Desktop/EDA/data/procesado/agujas.csv")

# %%
cat_azuelas = ['Context_artefacts::Site', 'Category', 'Context_artefacts::Region', 'Context_artefacts::Period', 'Context_artefacts::Type of context', 'Type']
distrib_cat(df_azuelas, cat_azuelas)

# %%
cat_hachas = ['Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 'Context_artefacts::Type of context', 'Type']
distrib_cat(df_hachas, cat_hachas)

# %%
cat_cinceles = ['Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 'Context_artefacts::Type of context', 'Type']
distrib_cat(df_cinceles, cat_cinceles)

# %%
cat_espejos = ['Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 'Context_artefacts::Type of context', 'Type']
distrib_cat(df_espejos, cat_espejos)

# %%
cat_sierras = ['Context_artefacts::Site', 'Context_artefacts::Region', 'Context_artefacts::Period', 'Type', 'Context_artefacts::Type of context', 'Category']

distrib_cat(df_sierras, cat_sierras)

# %%
cat_agujas = ['Context_artefacts::Site', 'Context_artefacts::Region', 'Category', 'Context_artefacts::Period', 'Context_artefacts::Type of context', 'Type']

distrib_cat(df_agujas, cat_agujas)
